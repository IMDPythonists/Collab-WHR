# %% [markdown]
# ## **Trabalho Integra School 2021**
# **Alunos:** Gabriel Vitor, João Felipe Medeiros e João Victor Soares
# <br>
# **Professor:** Carlos Arthur Guimarães
#
# - Problemática: Relatório sobre felicidade mundial comparando os anos anteriores com 2021. Pretendemos mostrar com essa pesquisa o notório crescimento da felicidade no Brasil
#
# - O que é: Histórico de crescimento da Felicidade Mundial de 2005 à 2021.
#
# - Fonte de Dados: [Kaggle](https://www.kaggle.com/ajaypalsinghlo/world-happiness-report-2021)
#
# - ONU 2030 Área e Objetivo: Saúde e Bem-Estar(3) & Paz, Justiça e Instituições Eficazes(16).

# %% [markdown]
# # 1- **Obtenção de Dados**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import plotly as plt
import plotly.graph_objects as go

# %%
whr = pd.read_csv("https://raw.githubusercontent.com/IMDPythonists/Collab-WHR/master/data/world-happiness-report.csv")
whr_2021 = pd.read_csv("https://raw.githubusercontent.com/IMDPythonists/Collab-WHR/master/data/world-happiness-report-2021.csv")
brazil = pd.read_csv("https://raw.githubusercontent.com/IMDPythonists/Collab-WHR/master/data/brazil.csv")

brazil
# Out:
#    Country name  year  ...  Positive affect  Negative affect
# 0        Brazil  2005  ...            0.818            0.302
# 1        Brazil  2007  ...            0.859            0.299
# 2        Brazil  2008  ...            0.820            0.265
# 3        Brazil  2009  ...            0.833            0.274
# 4        Brazil  2010  ...            0.817            0.250
# 5        Brazil  2011  ...            0.807            0.268
# 6        Brazil  2012  ...            0.755            0.350
# 7        Brazil  2013  ...            0.818            0.276
# 8        Brazil  2014  ...            0.788            0.274
# 9        Brazil  2015  ...            0.755            0.325
# 10       Brazil  2016  ...            0.763            0.302
# 11       Brazil  2017  ...            0.716            0.308
# 12       Brazil  2018  ...            0.750            0.350
# 13       Brazil  2019  ...            0.761            0.337
# ...

# %% [markdown]
# ##2-**Scrub**
#
# ###**Missingno**

# %%
import missingno as msno

msno.matrix(brazil)

# %%
msno.bar(brazil)

# %%
msno.heatmap(brazil)

# %%
msno.dendrogram(brazil)

# %% [markdown]
# trabalho feito especialmente pra mandar jv tomar no cu
# ##3-**Exploração de Dados**

# %%
brazil.shape
# Out:
# (16, 11)

# %%
brazil.corr()
# Out:
#                                       year  ...  Negative affect
# year                              1.000000  ...         0.699967
# Life Ladder                      -0.523212  ...        -0.758841
# Log GDP per capita                0.309771  ...        -0.172414
# Social support                   -0.242737  ...        -0.636877
# Healthy life expectancy at birth  0.993030  ...         0.665991
# Freedom to make life choices     -0.251595  ...         0.131491
# Generosity                       -0.318088  ...         0.057759
# Perceptions of corruption         0.468489  ...         0.342120
# Positive affect                  -0.882208  ...        -0.804989
# Negative affect                   0.699967  ...         1.000000
#
# [10 rows x 10 columns]
